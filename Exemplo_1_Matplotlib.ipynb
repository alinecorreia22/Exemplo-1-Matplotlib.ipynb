# %% [markdown]
# <a href="https://colab.research.google.com/github/alinecorreia22/Exemplo-1-Matplotlib.ipynb/blob/main/Exemplo_1_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PASSO A PASSO DO QUE FOI FEITO :
#
# *   Importação da biblioteca Matplotlib
# *   Geração do método de regressão
# *   Definição da regressão gerada (200 exemplos com caracteristicas envolvendo 1 unidade e um erro para representar em 30 unidades.)

# %%
import matplotlib

# %%
from sklearn.datasets import make_regression
x, y = make_regression(n_samples=200, n_features=1, noise=30)
import matplotlib.pyplot as  plt

# %%
plt.scatter(x,y)
plt.show()
